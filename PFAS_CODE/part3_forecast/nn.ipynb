# %%
import sys
sys.path.append('..')
import pandas as pd
import numpy as np
import myfunction as mf
path_data_raw = "C:/Users/dell/OneDrive/file/"
path_country_nc = "C:/Users/dell/OneDrive/file/nc"
path_one_spdb = 'C:/Users/dell/OneDrive/file/SPDB/'
drive_letter = 'E:'

path_pre = drive_letter + "/wyy/code_project/running_outcome/final_data/SPDB/part0_treat/pretreatment/"
path_match = drive_letter + "/wyy/code_project/running_outcome/final_data/SPDB/part0_treat/match/"
path_semdata = drive_letter + "/wyy/code_project/running_outcome/final_data/SPDB/part0_treat/semdata/"

path_2_preanalysis_data = drive_letter + "/wyy/code_project/running_outcome/final_data/SPDB/part2_sem/preanalysis/"
path_2_preanalysis_fig = drive_letter + "/wyy/code_project/running_outcome/final_fig/SPDB/part2_sem/preanalysis/"
path_3_sw_forecast = drive_letter + "/wyy/code_project/running_outcome/final_data/SPDB/part3_forecast/sw_forecast/"

path_temp = drive_letter + "/wyy/code_project/running_outcome/final_data/SPDB/temp/"

meta_name = "meta_data.csv"

list_pfas = ['PFBS', 'PFDA', 'PFHpA', 'PFHxA', 'PFHxS', 'PFNA', 'PFOA', 'PFOS', 'FOSA', 'PFDoDA', 'PFTeDA', 'PFUnDA', 'PFTrDA', 'HFPO-DA', 'PFBA', 'PFDS', 'PFHpS', 'PFNS', 'PFPeA', 'PFPeS']


list_color = ["#ee877c", "#8bd0e3", "#6abeae", "#808eaf", "#f7bba8", "#acb4cc", "#b5e0d5", "#e86462", "#a89687"]

# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import TensorDataset, Subset
import torch.nn.functional as F
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold
import numpy as np
import pandas as pd
import itertools

def start_cnn(df_o):
    data = df_o.copy()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    X = data.drop('value', axis=1)
    y = data['value']
    X = X.values.reshape(X.shape[0], X.shape[1], 1)
    y = y.values

    list_batch_size = [1024,2048,4096]
    list_conv1_outcome = [32, 64]
    list_fc1_outcome = [128,258]
    list_learn_rate = [0.001]
    list_epoch_range = [10000]

    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.float32)
    start_var_num = data.shape[1]-1


    def train_model(params, train_ids, test_ids):
        batch_size, fc1_outcome, fc2_outcome, learn_rate, epoch_range = params
        print("all param:", batch_size, fc1_outcome, fc2_outcome, learn_rate, epoch_range)
        class Net(nn.Module):
            def __init__(self):
                super(Net, self).__init__()
                self.conv1 = nn.Conv1d(start_var_num, fc1_outcome, 3, padding=1)  # Input channels, output channels, kernel size
                self.pool = nn.MaxPool1d(1)  # Kernel size
                self.fc1 = nn.Linear(fc1_outcome, fc2_outcome)  # Input features, output features
                self.dropout = nn.Dropout(0.0001)
                self.fc2 = nn.Linear(fc2_outcome, 1)

            def forward(self, x):
                x = self.pool(F.relu(self.conv1(x)))
                x = x.view(-1, fc1_outcome)
                x = F.relu(self.fc1(x))
                x = self.dropout(x)
                x = self.fc2(x)
                return x.view(-1)

        model = Net().to(device)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=learn_rate)

        train_subset = Subset(TensorDataset(X, y), train_ids)
        test_subset = Subset(TensorDataset(X, y), test_ids)

        train_loader = torch.utils.data.DataLoader(
                        train_subset, 
                        batch_size=batch_size)
        test_loader = torch.utils.data.DataLoader(
                        test_subset,
                        batch_size=batch_size)

        min_loss = float('inf') 
        epochs_no_improve = 0  
        for epoch in range(epoch_range): 
            total_loss = 0  
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                total_loss += loss.item()  

            avg_loss = total_loss / len(train_loader) 

            if avg_loss < min_loss:
                min_loss = avg_loss 
                epochs_no_improve = 0 
            else:
                epochs_no_improve += 1 

            if epochs_no_improve == 100:
                print('Early stopping after {} epochs'.format(epoch+1))
                break  

        model.eval()
        predictions = []
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            predictions.extend(outputs.detach().cpu().numpy())

        r2 = r2_score(y[test_ids].numpy(), predictions)
        mse = mean_squared_error(y[test_ids].numpy(), predictions)


        return r2, mse

    def grid_search(params):
        print('------------------CNN stsrt-----------------')
        kfold = KFold(n_splits=10, shuffle=True, random_state=202406)
        param_combinations = list(itertools.product(*params.values()))
        results = []
        for params in param_combinations:
            r2_scores = []
            mse_score = []
            for fold, (train_ids, test_ids) in enumerate(kfold.split(X)):
                print('fold', fold)
                r2, mse = train_model(params, train_ids, test_ids)
                r2_scores.append(r2)
                mse_score.append(mse)
            avg_r2 = np.mean(r2_scores)

            avg_mse = np.mean(mse_score)
            print('Average R^2 score:', avg_r2)
            print('Average MSE score:', avg_mse)
            results.append((params, r2_scores, avg_r2, avg_mse))
        return results

    param_grid = {
        'batch_size': list_batch_size,
        'conv1_outcome': list_conv1_outcome,
        'fc1_outcome': list_fc1_outcome,
        'learn_rate': list_learn_rate,
        'epoch_range': list_epoch_range
    }

    results = grid_search(param_grid)

    results_df = pd.DataFrame(results, columns=['params', 'r2_scores', 'avg_r2', 'avg_mse'])
    results_df[['batch_size', 'conv1_outcome', 'fc1_outcome', 'learn_rate', 'epoch_range']] = pd.DataFrame(results_df['params'].tolist(), index=results_df.index)
    results_df = results_df.drop('params', axis=1)
    results_df['rank'] = results_df['avg_r2'].rank(ascending=False)
    print('------------------CNN END-----------------')
    return results_df


def start_mlp(df_o):
    data = df_o.copy()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    X = data.drop('value', axis=1)
    y = data['value']
    X = data.drop('value', axis=1).values
    y = y.values
    start_var_num = data.shape[1]-1
    list_batch_size = [1024,2048,4096]
    list_conv1_outcome = [32, 64]
    list_fc1_outcome = [128,258]
    list_learn_rate = [0.001]
    list_epoch_range = [10000]


    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.float32)

    def train_model(params, train_ids, test_ids):
        batch_size, fc1_outcome, fc2_outcome, learn_rate, epoch_range = params
        print("all param:", batch_size, fc1_outcome, fc2_outcome, learn_rate, epoch_range)

        class MLP(nn.Module):
            def __init__(self):
                super(MLP, self).__init__()
                self.fc1 = nn.Linear(start_var_num, fc1_outcome)  # Input features, output features
                self.fc2 = nn.Linear(fc1_outcome, fc2_outcome)  # Input features, output features
                self.fc3 = nn.Linear(fc2_outcome, 512)
                self.fc4 = nn.Linear(512, 1)

            def forward(self, x):
                x = F.relu(self.fc1(x))
                x = F.relu(self.fc2(x))
                x = F.relu(self.fc3(x))
                x = self.fc4(x)
                return x.view(-1)

        model = MLP().to(device)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=learn_rate)

        train_subset = Subset(TensorDataset(X, y), train_ids)
        test_subset = Subset(TensorDataset(X, y), test_ids)

        train_loader = torch.utils.data.DataLoader(
                        train_subset, 
                        batch_size=batch_size)
        test_loader = torch.utils.data.DataLoader(
                        test_subset,
                        batch_size=batch_size)

        min_loss = float('inf') 
        epochs_no_improve = 0  
        for epoch in range(epoch_range): 
            total_loss = 0  
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                loss.backward()
                optimizer.step()

                total_loss += loss.item()  

            avg_loss = total_loss / len(train_loader) 

            if avg_loss < min_loss:
                min_loss = avg_loss 
                epochs_no_improve = 0 
            else:
                epochs_no_improve += 1 

            if epochs_no_improve == 100:
                print('Early stopping after {} epochs'.format(epoch+1))
                break  

        model.eval()
        predictions = []
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            predictions.extend(outputs.detach().cpu().numpy())

        r2 = r2_score(y[test_ids].numpy(), predictions)
        mse = mean_squared_error(y[test_ids].numpy(), predictions)

        return r2, mse

    def grid_search(params):
        print('------------------MLP stsrt-----------------')
        kfold = KFold(n_splits=10, shuffle=True, random_state=202406)
        param_combinations = list(itertools.product(*params.values()))
        results = []
        for params in param_combinations:
            r2_scores = []
            mse_score = []
            for fold, (train_ids, test_ids) in enumerate(kfold.split(X)):
                print('fold', fold)
                r2, mse = train_model(params, train_ids, test_ids)
                r2_scores.append(r2)
                mse_score.append(mse)
            avg_r2 = np.mean(r2_scores)

            avg_mse = np.mean(mse_score)
            print('Average R^2 score:', avg_r2)
            print('Average MSE score:', avg_mse)
            results.append((params, r2_scores, avg_r2, avg_mse))
        return results

    param_grid = {
        'batch_size': list_batch_size,
        'conv1_outcome': list_conv1_outcome,
        'fc1_outcome': list_fc1_outcome,
        'learn_rate': list_learn_rate,
        'epoch_range': list_epoch_range
    }

    results = grid_search(param_grid)

    results_df = pd.DataFrame(results, columns=['params', 'r2_scores', 'avg_r2', 'avg_mse'])
    results_df[['batch_size', 'conv1_outcome', 'fc1_outcome', 'learn_rate', 'epoch_range']] = pd.DataFrame(results_df['params'].tolist(), index=results_df.index)
    results_df = results_df.drop('params', axis=1)
    results_df['rank'] = results_df['avg_r2'].rank(ascending=False)
    print('------------------MLP END-----------------')
    return results_df

def get_nn_best_model(df_o):
    df = df_o.copy()

    grouped = df.groupby(['model'])

    results = pd.DataFrame()

    for name, group in grouped:

        max_row = group[group['avg_r2'] == group['avg_r2'].max()]

        results = pd.concat([results, max_row])
    return results

# %% [markdown]
# ### sw

# %%
path_sw_rfecv_data = drive_letter + '/wyy/code_project/running_outcome/final_data/SPDB/part3_forecast/sw_forecast/'
data = pd.read_csv(path_match + 'sw_match_treat.csv')
data['year'] = (data['year'] - 2000) / (2020 - 2000)
data = data[data['posname'].isin(list_pfas)]
columns_to_drop = ['lon_grid', 'lat_grid', 'posname']
data = data.drop(columns=columns_to_drop)
print(len(data.columns))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 57
# cuda

# %%
df_cnn_result = start_cnn(data)
df_cnn_result['model'] = 'CNN'
df_cnn_result.to_csv(path_sw_rfecv_data + 'cnn_cv_result.csv',index=False)


df_mlp_result = start_mlp(data)
df_mlp_result['model'] = 'MLP'
df_mlp_result.to_csv(path_sw_rfecv_data + 'mlp_cv_result.csv',index=False)

df_nn_result = pd.concat([df_cnn_result, df_mlp_result],axis=0)


results = get_nn_best_model(df_nn_result)
results.to_csv(path_sw_rfecv_data + 'nn_cv_best.csv', index=False)
# Out:
# ------------------CNN stsrt-----------------
# fold 0
# all param: 1024 32 128 0.001 10000
# Early stopping after 2118 epochs
# fold 1
# all param: 1024 32 128 0.001 10000
# Early stopping after 1457 epochs
# fold 2
# all param: 1024 32 128 0.001 10000
# Early stopping after 1491 epochs
# fold 3
# all param: 1024 32 128 0.001 10000
# Early stopping after 2112 epochs
# fold 4
# all param: 1024 32 128 0.001 10000
# Early stopping after 1936 epochs
# fold 5
# all param: 1024 32 128 0.001 10000
# Early stopping after 1329 epochs
# fold 6
# all param: 1024 32 128 0.001 10000
# Early stopping after 1537 epochs
# fold 7
# all param: 1024 32 128 0.001 10000
# Early stopping after 1762 epochs
# fold 8
# all param: 1024 32 128 0.001 10000
# Early stopping after 1145 epochs
# fold 9
# all param: 1024 32 128 0.001 10000
# Early stopping after 2519 epochs
# Average R^2 score: 0.7159924892391254
# Average MSE score: 0.28105375
# fold 0
# all param: 1024 32 258 0.001 10000
# Early stopping after 1832 epochs
# fold 1
# all param: 1024 32 258 0.001 10000
# Early stopping after 1053 epochs
# fold 2
# all param: 1024 32 258 0.001 10000
# Early stopping after 1605 epochs
# fold 3
# all param: 1024 32 258 0.001 10000
# Early stopping after 1994 epochs
# fold 4
# all param: 1024 32 258 0.001 10000
# Early stopping after 1804 epochs
# fold 5
# all param: 1024 32 258 0.001 10000
# Early stopping after 1380 epochs
# fold 6
# all param: 1024 32 258 0.001 10000
# Early stopping after 1717 epochs
# fold 7
# all param: 1024 32 258 0.001 10000
# Early stopping after 2043 epochs
# fold 8
# all param: 1024 32 258 0.001 10000
# Early stopping after 1351 epochs
# fold 9
# all param: 1024 32 258 0.001 10000
# Early stopping after 2530 epochs
# Average R^2 score: 0.7134666517662505
# Average MSE score: 0.2836817
# fold 0
# all param: 1024 64 128 0.001 10000
# Early stopping after 1563 epochs
# fold 1
# all param: 1024 64 128 0.001 10000
# Early stopping after 1140 epochs
# fold 2
# all param: 1024 64 128 0.001 10000
# Early stopping after 1890 epochs
# fold 3
# all param: 1024 64 128 0.001 10000
# Early stopping after 1689 epochs
# fold 4
# all param: 1024 64 128 0.001 10000
# Early stopping after 1846 epochs
# fold 5
# all param: 1024 64 128 0.001 10000
# Early stopping after 1953 epochs
# fold 6
# all param: 1024 64 128 0.001 10000
# Early stopping after 2221 epochs
# fold 7
# all param: 1024 64 128 0.001 10000
# Early stopping after 1922 epochs
# fold 8
# all param: 1024 64 128 0.001 10000
# Early stopping after 2184 epochs
# fold 9
# all param: 1024 64 128 0.001 10000
# Early stopping after 1716 epochs
# Average R^2 score: 0.7299565149447049
# Average MSE score: 0.26708588
# fold 0
# all param: 1024 64 258 0.001 10000
# Early stopping after 2356 epochs
# fold 1
# all param: 1024 64 258 0.001 10000
# Early stopping after 1117 epochs
# fold 2
# all param: 1024 64 258 0.001 10000
# Early stopping after 1154 epochs
# fold 3
# all param: 1024 64 258 0.001 10000
# Early stopping after 1272 epochs
# fold 4
# all param: 1024 64 258 0.001 10000
# Early stopping after 1533 epochs
# fold 5
# all param: 1024 64 258 0.001 10000
# Early stopping after 1588 epochs
# fold 6
# all param: 1024 64 258 0.001 10000
# Early stopping after 1344 epochs
# fold 7
# all param: 1024 64 258 0.001 10000
# Early stopping after 1580 epochs
# fold 8
# all param: 1024 64 258 0.001 10000
# Early stopping after 2335 epochs
# fold 9
# all param: 1024 64 258 0.001 10000
# Early stopping after 923 epochs
# Average R^2 score: 0.7386517769626254
# Average MSE score: 0.25872898
# fold 0
# all param: 2048 32 128 0.001 10000
# Early stopping after 2805 epochs
# fold 1
# all param: 2048 32 128 0.001 10000
# Early stopping after 3784 epochs
# fold 2
# all param: 2048 32 128 0.001 10000
# Early stopping after 1665 epochs
# fold 3
# all param: 2048 32 128 0.001 10000
# Early stopping after 3399 epochs
# fold 4
# all param: 2048 32 128 0.001 10000
# Early stopping after 3740 epochs
# fold 5
# all param: 2048 32 128 0.001 10000
# Early stopping after 2257 epochs
# fold 6
# all param: 2048 32 128 0.001 10000
# Early stopping after 4269 epochs
# fold 7
# all param: 2048 32 128 0.001 10000
# Early stopping after 1325 epochs
# fold 8
# all param: 2048 32 128 0.001 10000
# Early stopping after 1564 epochs
# fold 9
# all param: 2048 32 128 0.001 10000
# Early stopping after 2418 epochs
# Average R^2 score: 0.7306234455844596
# Average MSE score: 0.26651365
# fold 0
# all param: 2048 32 258 0.001 10000
# Early stopping after 1797 epochs
# fold 1
# all param: 2048 32 258 0.001 10000
# Early stopping after 1371 epochs
# fold 2
# all param: 2048 32 258 0.001 10000
# Early stopping after 2573 epochs
# fold 3
# all param: 2048 32 258 0.001 10000
# Early stopping after 1612 epochs
# fold 4
# all param: 2048 32 258 0.001 10000
# Early stopping after 2664 epochs
# fold 5
# all param: 2048 32 258 0.001 10000
# Early stopping after 3170 epochs
# fold 6
# all param: 2048 32 258 0.001 10000
# Early stopping after 3189 epochs
# fold 7
# all param: 2048 32 258 0.001 10000
# Early stopping after 2684 epochs
# fold 8
# all param: 2048 32 258 0.001 10000
# Early stopping after 2010 epochs
# fold 9
# all param: 2048 32 258 0.001 10000
# Early stopping after 2732 epochs
# Average R^2 score: 0.7328839888708367
# Average MSE score: 0.26446745
# fold 0
# all param: 2048 64 128 0.001 10000
# Early stopping after 2023 epochs
# fold 1
# all param: 2048 64 128 0.001 10000
# Early stopping after 917 epochs
# fold 2
# all param: 2048 64 128 0.001 10000
# Early stopping after 1671 epochs
# fold 3
# all param: 2048 64 128 0.001 10000
# Early stopping after 2148 epochs
# fold 4
# all param: 2048 64 128 0.001 10000
# Early stopping after 1868 epochs
# fold 5
# all param: 2048 64 128 0.001 10000
# Early stopping after 1094 epochs
# fold 6
# all param: 2048 64 128 0.001 10000
# Early stopping after 1357 epochs
# fold 7
# all param: 2048 64 128 0.001 10000
# Early stopping after 1064 epochs
# fold 8
# all param: 2048 64 128 0.001 10000
# Early stopping after 2727 epochs
# fold 9
# all param: 2048 64 128 0.001 10000
# Early stopping after 1803 epochs
# Average R^2 score: 0.7397063438687628
# Average MSE score: 0.2578535
# fold 0
# all param: 2048 64 258 0.001 10000
# Early stopping after 1915 epochs
# fold 1
# all param: 2048 64 258 0.001 10000
# Early stopping after 1544 epochs
# fold 2
# all param: 2048 64 258 0.001 10000
# Early stopping after 2051 epochs
# fold 3
# all param: 2048 64 258 0.001 10000
# Early stopping after 2236 epochs
# fold 4
# all param: 2048 64 258 0.001 10000
# Early stopping after 1258 epochs
# fold 5
# all param: 2048 64 258 0.001 10000
# Early stopping after 1843 epochs
# fold 6
# all param: 2048 64 258 0.001 10000
# Early stopping after 1116 epochs
# fold 7
# all param: 2048 64 258 0.001 10000
# Early stopping after 1744 epochs
# fold 8
# all param: 2048 64 258 0.001 10000
# Early stopping after 2907 epochs
# fold 9
# all param: 2048 64 258 0.001 10000
# Early stopping after 1663 epochs
# Average R^2 score: 0.7498771578248123
# Average MSE score: 0.24776006
# fold 0
# all param: 4096 32 128 0.001 10000
# Early stopping after 3406 epochs
# fold 1
# all param: 4096 32 128 0.001 10000
# Early stopping after 1581 epochs
# fold 2
# all param: 4096 32 128 0.001 10000
# Early stopping after 1626 epochs
# fold 3
# all param: 4096 32 128 0.001 10000
# Early stopping after 1489 epochs
# fold 4
# all param: 4096 32 128 0.001 10000
# Early stopping after 2461 epochs
# fold 5
# all param: 4096 32 128 0.001 10000
# Early stopping after 2414 epochs
# fold 6
# all param: 4096 32 128 0.001 10000
# Early stopping after 1774 epochs
# fold 7
# all param: 4096 32 128 0.001 10000
# Early stopping after 3783 epochs
# fold 8
# all param: 4096 32 128 0.001 10000
# Early stopping after 2342 epochs
# fold 9
# all param: 4096 32 128 0.001 10000
# Early stopping after 1679 epochs
# Average R^2 score: 0.7142000173242933
# Average MSE score: 0.28280488
# fold 0
# all param: 4096 32 258 0.001 10000
# Early stopping after 4609 epochs
# fold 1
# all param: 4096 32 258 0.001 10000
# Early stopping after 1399 epochs
# fold 2
# all param: 4096 32 258 0.001 10000
# Early stopping after 2604 epochs
# fold 3
# all param: 4096 32 258 0.001 10000
# Early stopping after 1967 epochs
# fold 4
# all param: 4096 32 258 0.001 10000
# Early stopping after 3065 epochs
# fold 5
# all param: 4096 32 258 0.001 10000
# Early stopping after 1781 epochs
# fold 6
# all param: 4096 32 258 0.001 10000
# Early stopping after 2586 epochs
# fold 7
# all param: 4096 32 258 0.001 10000
# Early stopping after 4133 epochs
# fold 8
# all param: 4096 32 258 0.001 10000
# Early stopping after 2318 epochs
# fold 9
# all param: 4096 32 258 0.001 10000
# Early stopping after 2207 epochs
# Average R^2 score: 0.7287561874051598
# Average MSE score: 0.2684251
# fold 0
# all param: 4096 64 128 0.001 10000
# Early stopping after 1196 epochs
# fold 1
# all param: 4096 64 128 0.001 10000
# Early stopping after 1241 epochs
# fold 2
# all param: 4096 64 128 0.001 10000
# Early stopping after 1033 epochs
# fold 3
# all param: 4096 64 128 0.001 10000
# Early stopping after 1466 epochs
# fold 4
# all param: 4096 64 128 0.001 10000
# Early stopping after 1091 epochs
# fold 5
# all param: 4096 64 128 0.001 10000
# Early stopping after 1771 epochs
# fold 6
# all param: 4096 64 128 0.001 10000
# Early stopping after 1065 epochs
# fold 7
# all param: 4096 64 128 0.001 10000
# Early stopping after 1334 epochs
# fold 8
# all param: 4096 64 128 0.001 10000
# Early stopping after 1341 epochs
# fold 9
# all param: 4096 64 128 0.001 10000
# Early stopping after 1127 epochs
# Average R^2 score: 0.7294216604886643
# Average MSE score: 0.26809755
# fold 0
# all param: 4096 64 258 0.001 10000
# Early stopping after 1385 epochs
# fold 1
# all param: 4096 64 258 0.001 10000
# Early stopping after 1282 epochs
# fold 2
# all param: 4096 64 258 0.001 10000
# Early stopping after 1395 epochs
# fold 3
# all param: 4096 64 258 0.001 10000
# Early stopping after 1064 epochs
# fold 4
# all param: 4096 64 258 0.001 10000
# Early stopping after 1514 epochs
# fold 5
# all param: 4096 64 258 0.001 10000
# Early stopping after 895 epochs
# fold 6
# all param: 4096 64 258 0.001 10000
# Early stopping after 961 epochs
# fold 7
# all param: 4096 64 258 0.001 10000
# Early stopping after 1406 epochs
# fold 8
# all param: 4096 64 258 0.001 10000
# Early stopping after 1267 epochs
# fold 9
# all param: 4096 64 258 0.001 10000
# Early stopping after 1493 epochs
# Average R^2 score: 0.7398859175063227
# Average MSE score: 0.25758183
# ------------------CNN END-----------------
# ------------------MLP stsrt-----------------
# fold 0
# all param: 1024 32 128 0.001 10000
# Early stopping after 823 epochs
# fold 1
# all param: 1024 32 128 0.001 10000
# Early stopping after 1353 epochs
# fold 2
# all param: 1024 32 128 0.001 10000
# Early stopping after 1160 epochs
# fold 3
# all param: 1024 32 128 0.001 10000
# Early stopping after 1100 epochs
# fold 4
# all param: 1024 32 128 0.001 10000
# Early stopping after 1293 epochs
# fold 5
# all param: 1024 32 128 0.001 10000
# Early stopping after 1203 epochs
# fold 6
# all param: 1024 32 128 0.001 10000
# Early stopping after 920 epochs
# fold 7
# all param: 1024 32 128 0.001 10000
# Early stopping after 1215 epochs
# fold 8
# all param: 1024 32 128 0.001 10000
# Early stopping after 1008 epochs
# fold 9
# all param: 1024 32 128 0.001 10000
# Early stopping after 1048 epochs
# Average R^2 score: 0.7170001203983685
# Average MSE score: 0.28000048
# fold 0
# all param: 1024 32 258 0.001 10000
# Early stopping after 857 epochs
# fold 1
# all param: 1024 32 258 0.001 10000
# Early stopping after 961 epochs
# fold 2
# all param: 1024 32 258 0.001 10000
# Early stopping after 1481 epochs
# fold 3
# all param: 1024 32 258 0.001 10000
# Early stopping after 1067 epochs
# fold 4
# all param: 1024 32 258 0.001 10000
# Early stopping after 1184 epochs
# fold 5
# all param: 1024 32 258 0.001 10000
# Early stopping after 1041 epochs
# fold 6
# all param: 1024 32 258 0.001 10000
# Early stopping after 956 epochs
# fold 7
# all param: 1024 32 258 0.001 10000
# Early stopping after 1059 epochs
# fold 8
# all param: 1024 32 258 0.001 10000
# Early stopping after 945 epochs
# fold 9
# all param: 1024 32 258 0.001 10000
# Early stopping after 1143 epochs
# Average R^2 score: 0.7193415468953652
# Average MSE score: 0.27799958
# fold 0
# all param: 1024 64 128 0.001 10000
# Early stopping after 1269 epochs
# fold 1
# all param: 1024 64 128 0.001 10000
# Early stopping after 944 epochs
# fold 2
# all param: 1024 64 128 0.001 10000
# Early stopping after 1189 epochs
# fold 3
# all param: 1024 64 128 0.001 10000
# Early stopping after 696 epochs
# fold 4
# all param: 1024 64 128 0.001 10000
# Early stopping after 1370 epochs
# fold 5
# all param: 1024 64 128 0.001 10000
# Early stopping after 932 epochs
# fold 6
# all param: 1024 64 128 0.001 10000
# Early stopping after 729 epochs
# fold 7
# all param: 1024 64 128 0.001 10000
# Early stopping after 1206 epochs
# fold 8
# all param: 1024 64 128 0.001 10000
# Early stopping after 1150 epochs
# fold 9
# all param: 1024 64 128 0.001 10000
# Early stopping after 629 epochs
# Average R^2 score: 0.7318787383817148
# Average MSE score: 0.2654198
# fold 0
# all param: 1024 64 258 0.001 10000
# Early stopping after 903 epochs
# fold 1
# all param: 1024 64 258 0.001 10000
# Early stopping after 765 epochs
# fold 2
# all param: 1024 64 258 0.001 10000
# Early stopping after 890 epochs
# fold 3
# all param: 1024 64 258 0.001 10000
# Early stopping after 961 epochs
# fold 4
# all param: 1024 64 258 0.001 10000
# Early stopping after 796 epochs
# fold 5
# all param: 1024 64 258 0.001 10000
# Early stopping after 831 epochs
# fold 6
# all param: 1024 64 258 0.001 10000
# Early stopping after 816 epochs
# fold 7
# all param: 1024 64 258 0.001 10000
# Early stopping after 1041 epochs
# fold 8
# all param: 1024 64 258 0.001 10000
# Early stopping after 895 epochs
# fold 9
# all param: 1024 64 258 0.001 10000
# Early stopping after 878 epochs
# Average R^2 score: 0.7399869575354783
# Average MSE score: 0.25767204
# fold 0
# all param: 2048 32 128 0.001 10000
# Early stopping after 1395 epochs
# fold 1
# all param: 2048 32 128 0.001 10000
# Early stopping after 1643 epochs
# fold 2
# all param: 2048 32 128 0.001 10000
# Early stopping after 1757 epochs
# fold 3
# all param: 2048 32 128 0.001 10000
# Early stopping after 1370 epochs
# fold 4
# all param: 2048 32 128 0.001 10000
# Early stopping after 1100 epochs
# fold 5
# all param: 2048 32 128 0.001 10000
# Early stopping after 1761 epochs
# fold 6
# all param: 2048 32 128 0.001 10000
# Early stopping after 2208 epochs
# fold 7
# all param: 2048 32 128 0.001 10000
# Early stopping after 1266 epochs
# fold 8
# all param: 2048 32 128 0.001 10000
# Early stopping after 1383 epochs
# fold 9
# all param: 2048 32 128 0.001 10000
# Early stopping after 1075 epochs
# Average R^2 score: 0.7181749668974856
# Average MSE score: 0.2788617
# fold 0
# all param: 2048 32 258 0.001 10000
# Early stopping after 1544 epochs
# fold 1
# all param: 2048 32 258 0.001 10000
# Early stopping after 1507 epochs
# fold 2
# all param: 2048 32 258 0.001 10000
# Early stopping after 1133 epochs
# fold 3
# all param: 2048 32 258 0.001 10000
# Early stopping after 1157 epochs
# fold 4
# all param: 2048 32 258 0.001 10000
# Early stopping after 1154 epochs
# fold 5
# all param: 2048 32 258 0.001 10000
# Early stopping after 1272 epochs
# fold 6
# all param: 2048 32 258 0.001 10000
# Early stopping after 1057 epochs
# fold 7
# all param: 2048 32 258 0.001 10000
# Early stopping after 1475 epochs
# fold 8
# all param: 2048 32 258 0.001 10000
# Early stopping after 1447 epochs
# fold 9
# all param: 2048 32 258 0.001 10000
# Early stopping after 1423 epochs
# Average R^2 score: 0.7186237685464113
# Average MSE score: 0.27880162
# fold 0
# all param: 2048 64 128 0.001 10000
# Early stopping after 1026 epochs
# fold 1
# all param: 2048 64 128 0.001 10000
# Early stopping after 1279 epochs
# fold 2
# all param: 2048 64 128 0.001 10000
# Early stopping after 1501 epochs
# fold 3
# all param: 2048 64 128 0.001 10000
# Early stopping after 944 epochs
# fold 4
# all param: 2048 64 128 0.001 10000
# Early stopping after 1040 epochs
# fold 5
# all param: 2048 64 128 0.001 10000
# Early stopping after 1250 epochs
# fold 6
# all param: 2048 64 128 0.001 10000
# Early stopping after 1241 epochs
# fold 7
# all param: 2048 64 128 0.001 10000
# Early stopping after 1643 epochs
# fold 8
# all param: 2048 64 128 0.001 10000
# Early stopping after 1521 epochs
# fold 9
# all param: 2048 64 128 0.001 10000
# Early stopping after 1166 epochs
# Average R^2 score: 0.7447599262989065
# Average MSE score: 0.25269303
# fold 0
# all param: 2048 64 258 0.001 10000
# Early stopping after 807 epochs
# fold 1
# all param: 2048 64 258 0.001 10000
# Early stopping after 1016 epochs
# fold 2
# all param: 2048 64 258 0.001 10000
# Early stopping after 1278 epochs
# fold 3
# all param: 2048 64 258 0.001 10000
# Early stopping after 1176 epochs
# fold 4
# all param: 2048 64 258 0.001 10000
# Early stopping after 792 epochs
# fold 5
# all param: 2048 64 258 0.001 10000
# Early stopping after 1166 epochs
# fold 6
# all param: 2048 64 258 0.001 10000
# Early stopping after 1175 epochs
# fold 7
# all param: 2048 64 258 0.001 10000
# Early stopping after 1225 epochs
# fold 8
# all param: 2048 64 258 0.001 10000
# Early stopping after 791 epochs
# fold 9
# all param: 2048 64 258 0.001 10000
# Early stopping after 1054 epochs
# Average R^2 score: 0.7512029570599565
# Average MSE score: 0.2464335
# fold 0
# all param: 4096 32 128 0.001 10000
# Early stopping after 1756 epochs
# fold 1
# all param: 4096 32 128 0.001 10000
# Early stopping after 1279 epochs
# fold 2
# all param: 4096 32 128 0.001 10000
# Early stopping after 2315 epochs
# fold 3
# all param: 4096 32 128 0.001 10000
# Early stopping after 1351 epochs
# fold 4
# all param: 4096 32 128 0.001 10000
# Early stopping after 1696 epochs
# fold 5
# all param: 4096 32 128 0.001 10000
# Early stopping after 1710 epochs
# fold 6
# all param: 4096 32 128 0.001 10000
# Early stopping after 2016 epochs
# fold 7
# all param: 4096 32 128 0.001 10000
# Early stopping after 2352 epochs
# fold 8
# all param: 4096 32 128 0.001 10000
# Early stopping after 1522 epochs
# fold 9
# all param: 4096 32 128 0.001 10000
# Early stopping after 3153 epochs
# Average R^2 score: 0.7330832693602927
# Average MSE score: 0.26409596
# fold 0
# all param: 4096 32 258 0.001 10000
# Early stopping after 1322 epochs
# fold 1
# all param: 4096 32 258 0.001 10000
# Early stopping after 2200 epochs
# fold 2
# all param: 4096 32 258 0.001 10000
# Early stopping after 1590 epochs
# fold 3
# all param: 4096 32 258 0.001 10000
# Early stopping after 2346 epochs
# fold 4
# all param: 4096 32 258 0.001 10000
# Early stopping after 2128 epochs
# fold 5
# all param: 4096 32 258 0.001 10000
# Early stopping after 2135 epochs
# fold 6
# all param: 4096 32 258 0.001 10000
# Early stopping after 954 epochs
# fold 7
# all param: 4096 32 258 0.001 10000
# Early stopping after 1475 epochs
# fold 8
# all param: 4096 32 258 0.001 10000
# Early stopping after 1506 epochs
# fold 9
# all param: 4096 32 258 0.001 10000
# Early stopping after 1525 epochs
# Average R^2 score: 0.733841763495972
# Average MSE score: 0.263473
# fold 0
# all param: 4096 64 128 0.001 10000
# Early stopping after 1503 epochs
# fold 1
# all param: 4096 64 128 0.001 10000
# Early stopping after 1792 epochs
# fold 2
# all param: 4096 64 128 0.001 10000
# Early stopping after 1373 epochs
# fold 3
# all param: 4096 64 128 0.001 10000
# Early stopping after 1243 epochs
# fold 4
# all param: 4096 64 128 0.001 10000
# Early stopping after 1596 epochs
# fold 5
# all param: 4096 64 128 0.001 10000
# Early stopping after 1127 epochs
# fold 6
# all param: 4096 64 128 0.001 10000
# Early stopping after 1977 epochs
# fold 7
# all param: 4096 64 128 0.001 10000
# Early stopping after 1287 epochs
# fold 8
# all param: 4096 64 128 0.001 10000
# Early stopping after 1266 epochs
# fold 9
# all param: 4096 64 128 0.001 10000
# Early stopping after 911 epochs
# Average R^2 score: 0.7392895321400721
# Average MSE score: 0.2580532
# fold 0
# all param: 4096 64 258 0.001 10000
# Early stopping after 1504 epochs
# fold 1
# all param: 4096 64 258 0.001 10000
# Early stopping after 1426 epochs
# fold 2
# all param: 4096 64 258 0.001 10000
# Early stopping after 1302 epochs
# fold 3
# all param: 4096 64 258 0.001 10000
# Early stopping after 990 epochs
# fold 4
# all param: 4096 64 258 0.001 10000
# Early stopping after 1208 epochs
# fold 5
# all param: 4096 64 258 0.001 10000
# Early stopping after 1196 epochs
# fold 6
# all param: 4096 64 258 0.001 10000
# Early stopping after 1254 epochs
# fold 7
# all param: 4096 64 258 0.001 10000
# Early stopping after 1440 epochs
# fold 8
# all param: 4096 64 258 0.001 10000
# Early stopping after 1407 epochs
# fold 9
# all param: 4096 64 258 0.001 10000
# Early stopping after 1302 epochs
# Average R^2 score: 0.7364704017614213
# Average MSE score: 0.26052034
# ------------------MLP END-----------------

# %% [markdown]
# ### lr

# %%
path_lr_rfecv_data = drive_letter + '/wyy/code_project/running_outcome/final_data/SPDB/part3_forecast/lr_forecast/'
data = pd.read_csv(path_match + 'lr_match_treat_full.csv')
data['year'] = (data['year'] - 2000) / (2020 - 2000)
data = data[data['posname'].isin(list_pfas)]
columns_to_drop = ['lon_grid', 'lat_grid', 'posname']
data = data.drop(columns=columns_to_drop)
print(len(data.columns))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 64
# cuda

# %%
df_cnn_result = start_cnn(data)
df_cnn_result['model'] = 'CNN'
df_cnn_result.to_csv(path_lr_rfecv_data + 'cnn_cv_result.csv',index=False)


df_mlp_result = start_mlp(data)
df_mlp_result['model'] = 'MLP'
df_mlp_result.to_csv(path_lr_rfecv_data + 'mlp_cv_result.csv',index=False)

df_nn_result = pd.concat([df_cnn_result, df_mlp_result],axis=0)


results = get_nn_best_model(df_nn_result)
results.to_csv(path_lr_rfecv_data + 'nn_cv_best.csv', index=False)
# Out:
# ------------------CNN stsrt-----------------
# fold 0
# all param: 1024 32 128 0.001 10000
# Early stopping after 950 epochs
# fold 1
# all param: 1024 32 128 0.001 10000
# Early stopping after 819 epochs
# fold 2
# all param: 1024 32 128 0.001 10000
# Early stopping after 862 epochs
# fold 3
# all param: 1024 32 128 0.001 10000
# Early stopping after 1226 epochs
# fold 4
# all param: 1024 32 128 0.001 10000
# Early stopping after 1182 epochs
# fold 5
# all param: 1024 32 128 0.001 10000
# Early stopping after 988 epochs
# fold 6
# all param: 1024 32 128 0.001 10000
# Early stopping after 1330 epochs
# fold 7
# all param: 1024 32 128 0.001 10000
# Early stopping after 685 epochs
# fold 8
# all param: 1024 32 128 0.001 10000
# Early stopping after 1039 epochs
# fold 9
# all param: 1024 32 128 0.001 10000
# Early stopping after 986 epochs
# Average R^2 score: 0.7380068519468036
# Average MSE score: 0.273091
# fold 0
# all param: 1024 32 258 0.001 10000
# Early stopping after 785 epochs
# fold 1
# all param: 1024 32 258 0.001 10000
# Early stopping after 1130 epochs
# fold 2
# all param: 1024 32 258 0.001 10000
# Early stopping after 774 epochs
# fold 3
# all param: 1024 32 258 0.001 10000
# Early stopping after 957 epochs
# fold 4
# all param: 1024 32 258 0.001 10000
# Early stopping after 1011 epochs
# fold 5
# all param: 1024 32 258 0.001 10000
# Early stopping after 701 epochs
# fold 6
# all param: 1024 32 258 0.001 10000
# Early stopping after 899 epochs
# fold 7
# all param: 1024 32 258 0.001 10000
# Early stopping after 770 epochs
# fold 8
# all param: 1024 32 258 0.001 10000
# Early stopping after 407 epochs
# fold 9
# all param: 1024 32 258 0.001 10000
# Early stopping after 743 epochs
# Average R^2 score: 0.7389497424882292
# Average MSE score: 0.27189448
# fold 0
# all param: 1024 64 128 0.001 10000
# Early stopping after 912 epochs
# fold 1
# all param: 1024 64 128 0.001 10000
# Early stopping after 923 epochs
# fold 2
# all param: 1024 64 128 0.001 10000
# Early stopping after 895 epochs
# fold 3
# all param: 1024 64 128 0.001 10000
# Early stopping after 834 epochs
# fold 4
# all param: 1024 64 128 0.001 10000
# Early stopping after 879 epochs
# fold 5
# all param: 1024 64 128 0.001 10000
# Early stopping after 830 epochs
# fold 6
# all param: 1024 64 128 0.001 10000
# Early stopping after 1192 epochs
# fold 7
# all param: 1024 64 128 0.001 10000
# Early stopping after 1055 epochs
# fold 8
# all param: 1024 64 128 0.001 10000
# Early stopping after 1110 epochs
# fold 9
# all param: 1024 64 128 0.001 10000
# Early stopping after 971 epochs
# Average R^2 score: 0.745915801740769
# Average MSE score: 0.26482424
# fold 0
# all param: 1024 64 258 0.001 10000
# Early stopping after 557 epochs
# fold 1
# all param: 1024 64 258 0.001 10000
# Early stopping after 1508 epochs
# fold 2
# all param: 1024 64 258 0.001 10000
# Early stopping after 1275 epochs
# fold 3
# all param: 1024 64 258 0.001 10000
# Early stopping after 1021 epochs
# fold 4
# all param: 1024 64 258 0.001 10000
# Early stopping after 972 epochs
# fold 5
# all param: 1024 64 258 0.001 10000
# Early stopping after 826 epochs
# fold 6
# all param: 1024 64 258 0.001 10000
# Early stopping after 622 epochs
# fold 7
# all param: 1024 64 258 0.001 10000
# Early stopping after 733 epochs
# fold 8
# all param: 1024 64 258 0.001 10000
# Early stopping after 1067 epochs
# fold 9
# all param: 1024 64 258 0.001 10000
# Early stopping after 1123 epochs
# Average R^2 score: 0.736938673531131
# Average MSE score: 0.2742887
# fold 0
# all param: 2048 32 128 0.001 10000
# Early stopping after 1448 epochs
# fold 1
# all param: 2048 32 128 0.001 10000
# Early stopping after 1090 epochs
# fold 2
# all param: 2048 32 128 0.001 10000
# Early stopping after 689 epochs
# fold 3
# all param: 2048 32 128 0.001 10000
# Early stopping after 859 epochs
# fold 4
# all param: 2048 32 128 0.001 10000
# Early stopping after 468 epochs
# fold 5
# all param: 2048 32 128 0.001 10000
# Early stopping after 1484 epochs
# fold 6
# all param: 2048 32 128 0.001 10000
# Early stopping after 1386 epochs
# fold 7
# all param: 2048 32 128 0.001 10000
# Early stopping after 1397 epochs
# fold 8
# all param: 2048 32 128 0.001 10000
# Early stopping after 566 epochs
# fold 9
# all param: 2048 32 128 0.001 10000
# Early stopping after 1349 epochs
# Average R^2 score: 0.7447866813473697
# Average MSE score: 0.26611254
# fold 0
# all param: 2048 32 258 0.001 10000
# Early stopping after 798 epochs
# fold 1
# all param: 2048 32 258 0.001 10000
# Early stopping after 655 epochs
# fold 2
# all param: 2048 32 258 0.001 10000
# Early stopping after 1265 epochs
# fold 3
# all param: 2048 32 258 0.001 10000
# Early stopping after 2259 epochs
# fold 4
# all param: 2048 32 258 0.001 10000
# Early stopping after 1075 epochs
# fold 5
# all param: 2048 32 258 0.001 10000
# Early stopping after 1345 epochs
# fold 6
# all param: 2048 32 258 0.001 10000
# Early stopping after 599 epochs
# fold 7
# all param: 2048 32 258 0.001 10000
# Early stopping after 562 epochs
# fold 8
# all param: 2048 32 258 0.001 10000
# Early stopping after 1352 epochs
# fold 9
# all param: 2048 32 258 0.001 10000
# Early stopping after 2999 epochs
# Average R^2 score: 0.7448057538701962
# Average MSE score: 0.26611945
# fold 0
# all param: 2048 64 128 0.001 10000
# Early stopping after 913 epochs
# fold 1
# all param: 2048 64 128 0.001 10000
# Early stopping after 972 epochs
# fold 2
# all param: 2048 64 128 0.001 10000
# Early stopping after 1215 epochs
# fold 3
# all param: 2048 64 128 0.001 10000
# Early stopping after 1107 epochs
# fold 4
# all param: 2048 64 128 0.001 10000
# Early stopping after 1388 epochs
# fold 5
# all param: 2048 64 128 0.001 10000
# Early stopping after 1214 epochs
# fold 6
# all param: 2048 64 128 0.001 10000
# Early stopping after 1408 epochs
# fold 7
# all param: 2048 64 128 0.001 10000
# Early stopping after 1531 epochs
# fold 8
# all param: 2048 64 128 0.001 10000
# Early stopping after 1297 epochs
# fold 9
# all param: 2048 64 128 0.001 10000
# Early stopping after 1027 epochs
# Average R^2 score: 0.7489162521478975
# Average MSE score: 0.26157814
# fold 0
# all param: 2048 64 258 0.001 10000
# Early stopping after 739 epochs
# fold 1
# all param: 2048 64 258 0.001 10000
# Early stopping after 944 epochs
# fold 2
# all param: 2048 64 258 0.001 10000
# Early stopping after 1070 epochs
# fold 3
# all param: 2048 64 258 0.001 10000
# Early stopping after 1031 epochs
# fold 4
# all param: 2048 64 258 0.001 10000
# Early stopping after 934 epochs
# fold 5
# all param: 2048 64 258 0.001 10000
# Early stopping after 2035 epochs
# fold 6
# all param: 2048 64 258 0.001 10000
# Early stopping after 1555 epochs
# fold 7
# all param: 2048 64 258 0.001 10000
# Early stopping after 1368 epochs
# fold 8
# all param: 2048 64 258 0.001 10000
# Early stopping after 1151 epochs
# fold 9
# all param: 2048 64 258 0.001 10000
# Early stopping after 737 epochs
# Average R^2 score: 0.7545963355088061
# Average MSE score: 0.25562412
# fold 0
# all param: 4096 32 128 0.001 10000
# Early stopping after 3040 epochs
# fold 1
# all param: 4096 32 128 0.001 10000
# Early stopping after 2199 epochs
# fold 2
# all param: 4096 32 128 0.001 10000
# Early stopping after 3775 epochs
# fold 3
# all param: 4096 32 128 0.001 10000
# Early stopping after 3801 epochs
# fold 4
# all param: 4096 32 128 0.001 10000
# Early stopping after 1653 epochs
# fold 5
# all param: 4096 32 128 0.001 10000
# Early stopping after 1215 epochs
# fold 6
# all param: 4096 32 128 0.001 10000
# Early stopping after 3174 epochs
# fold 7
# all param: 4096 32 128 0.001 10000
# Early stopping after 4625 epochs
# fold 8
# all param: 4096 32 128 0.001 10000
# Early stopping after 2270 epochs
# fold 9
# all param: 4096 32 128 0.001 10000
# Early stopping after 2841 epochs
# Average R^2 score: 0.7415277845370271
# Average MSE score: 0.26934463
# fold 0
# all param: 4096 32 258 0.001 10000
# Early stopping after 1349 epochs
# fold 1
# all param: 4096 32 258 0.001 10000
# Early stopping after 3267 epochs
# fold 2
# all param: 4096 32 258 0.001 10000
# Early stopping after 3461 epochs
# fold 3
# all param: 4096 32 258 0.001 10000
# Early stopping after 1628 epochs
# fold 4
# all param: 4096 32 258 0.001 10000
# Early stopping after 3675 epochs
# fold 5
# all param: 4096 32 258 0.001 10000
# Early stopping after 1890 epochs
# fold 6
# all param: 4096 32 258 0.001 10000
# Early stopping after 3926 epochs
# fold 7
# all param: 4096 32 258 0.001 10000
# Early stopping after 3738 epochs
# fold 8
# all param: 4096 32 258 0.001 10000
# Early stopping after 3550 epochs
# fold 9
# all param: 4096 32 258 0.001 10000
# Early stopping after 2059 epochs
# Average R^2 score: 0.7433406429511006
# Average MSE score: 0.2677344
# fold 0
# all param: 4096 64 128 0.001 10000
# Early stopping after 2245 epochs
# fold 1
# all param: 4096 64 128 0.001 10000
# Early stopping after 2830 epochs
# fold 2
# all param: 4096 64 128 0.001 10000
# Early stopping after 3762 epochs
# fold 3
# all param: 4096 64 128 0.001 10000
# Early stopping after 3782 epochs
# fold 4
# all param: 4096 64 128 0.001 10000
# Early stopping after 2195 epochs
# fold 5
# all param: 4096 64 128 0.001 10000
# Early stopping after 3913 epochs
# fold 6
# all param: 4096 64 128 0.001 10000
# Early stopping after 3550 epochs
# fold 7
# all param: 4096 64 128 0.001 10000
# Early stopping after 4325 epochs
# fold 8
# all param: 4096 64 128 0.001 10000
# Early stopping after 2552 epochs
# fold 9
# all param: 4096 64 128 0.001 10000
# Early stopping after 3419 epochs
# Average R^2 score: 0.7533323836387583
# Average MSE score: 0.25708932
# fold 0
# all param: 4096 64 258 0.001 10000
# Early stopping after 3264 epochs
# fold 1
# all param: 4096 64 258 0.001 10000
# Early stopping after 2803 epochs
# fold 2
# all param: 4096 64 258 0.001 10000
# Early stopping after 4054 epochs
# fold 3
# all param: 4096 64 258 0.001 10000
# Early stopping after 3344 epochs
# fold 4
# all param: 4096 64 258 0.001 10000
# Early stopping after 3027 epochs
# fold 5
# all param: 4096 64 258 0.001 10000
# Early stopping after 2621 epochs
# fold 6
# all param: 4096 64 258 0.001 10000
# Early stopping after 1307 epochs
# fold 7
# all param: 4096 64 258 0.001 10000
# Early stopping after 1536 epochs
# fold 8
# all param: 4096 64 258 0.001 10000
# Early stopping after 3979 epochs
# fold 9
# all param: 4096 64 258 0.001 10000
# Early stopping after 3765 epochs
# Average R^2 score: 0.7490690270304986
# Average MSE score: 0.26172554
# ------------------CNN END-----------------
# ------------------MLP stsrt-----------------
# fold 0
# all param: 1024 32 128 0.001 10000
# Early stopping after 1037 epochs
# fold 1
# all param: 1024 32 128 0.001 10000
# Early stopping after 707 epochs
# fold 2
# all param: 1024 32 128 0.001 10000
# Early stopping after 1171 epochs
# fold 3
# all param: 1024 32 128 0.001 10000
# Early stopping after 1316 epochs
# fold 4
# all param: 1024 32 128 0.001 10000
# Early stopping after 1156 epochs
# fold 5
# all param: 1024 32 128 0.001 10000
# Early stopping after 1227 epochs
# fold 6
# all param: 1024 32 128 0.001 10000
# Early stopping after 1117 epochs
# fold 7
# all param: 1024 32 128 0.001 10000
# Early stopping after 1089 epochs
# fold 8
# all param: 1024 32 128 0.001 10000
# Early stopping after 1493 epochs
# fold 9
# all param: 1024 32 128 0.001 10000
# Early stopping after 910 epochs
# Average R^2 score: 0.7027297674189323
# Average MSE score: 0.30979747
# fold 0
# all param: 1024 32 258 0.001 10000
# Early stopping after 919 epochs
# fold 1
# all param: 1024 32 258 0.001 10000
# Early stopping after 905 epochs
# fold 2
# all param: 1024 32 258 0.001 10000
# Early stopping after 1272 epochs
# fold 3
# all param: 1024 32 258 0.001 10000
# Early stopping after 1288 epochs
# fold 4
# all param: 1024 32 258 0.001 10000
# Early stopping after 959 epochs
# fold 5
# all param: 1024 32 258 0.001 10000
# Early stopping after 1271 epochs
# fold 6
# all param: 1024 32 258 0.001 10000
# Early stopping after 995 epochs
# fold 7
# all param: 1024 32 258 0.001 10000
# Early stopping after 1001 epochs
# fold 8
# all param: 1024 32 258 0.001 10000
# Early stopping after 1009 epochs
# fold 9
# all param: 1024 32 258 0.001 10000
# Early stopping after 1186 epochs
# Average R^2 score: 0.6998881302076201
# Average MSE score: 0.31267792
# fold 0
# all param: 1024 64 128 0.001 10000
# Early stopping after 921 epochs
# fold 1
# all param: 1024 64 128 0.001 10000
# Early stopping after 773 epochs
# fold 2
# all param: 1024 64 128 0.001 10000
# Early stopping after 1322 epochs
# fold 3
# all param: 1024 64 128 0.001 10000
# Early stopping after 1075 epochs
# fold 4
# all param: 1024 64 128 0.001 10000
# Early stopping after 1007 epochs
# fold 5
# all param: 1024 64 128 0.001 10000
# Early stopping after 711 epochs
# fold 6
# all param: 1024 64 128 0.001 10000
# Early stopping after 1231 epochs
# fold 7
# all param: 1024 64 128 0.001 10000
# Early stopping after 1233 epochs
# fold 8
# all param: 1024 64 128 0.001 10000
# Early stopping after 866 epochs
# fold 9
# all param: 1024 64 128 0.001 10000
# Early stopping after 1149 epochs
# Average R^2 score: 0.7109311176498333
# Average MSE score: 0.30131188
# fold 0
# all param: 1024 64 258 0.001 10000
# Early stopping after 1092 epochs
# fold 1
# all param: 1024 64 258 0.001 10000
# Early stopping after 854 epochs
# fold 2
# all param: 1024 64 258 0.001 10000
# Early stopping after 905 epochs
# fold 3
# all param: 1024 64 258 0.001 10000
# Early stopping after 753 epochs
# fold 4
# all param: 1024 64 258 0.001 10000
# Early stopping after 785 epochs
# fold 5
# all param: 1024 64 258 0.001 10000
# Early stopping after 901 epochs
# fold 6
# all param: 1024 64 258 0.001 10000
# Early stopping after 944 epochs
# fold 7
# all param: 1024 64 258 0.001 10000
# Early stopping after 845 epochs
# fold 8
# all param: 1024 64 258 0.001 10000
# Early stopping after 1068 epochs
# fold 9
# all param: 1024 64 258 0.001 10000
# Early stopping after 907 epochs
# Average R^2 score: 0.7162053921069969
# Average MSE score: 0.29598844
# fold 0
# all param: 2048 32 128 0.001 10000
# Early stopping after 645 epochs
# fold 1
# all param: 2048 32 128 0.001 10000
# Early stopping after 1336 epochs
# fold 2
# all param: 2048 32 128 0.001 10000
# Early stopping after 1226 epochs
# fold 3
# all param: 2048 32 128 0.001 10000
# Early stopping after 905 epochs
# fold 4
# all param: 2048 32 128 0.001 10000
# Early stopping after 661 epochs
# fold 5
# all param: 2048 32 128 0.001 10000
# Early stopping after 950 epochs
# fold 6
# all param: 2048 32 128 0.001 10000
# Early stopping after 1073 epochs
# fold 7
# all param: 2048 32 128 0.001 10000
# Early stopping after 1708 epochs
# fold 8
# all param: 2048 32 128 0.001 10000
# Early stopping after 1148 epochs
# fold 9
# all param: 2048 32 128 0.001 10000
# Early stopping after 1310 epochs
# Average R^2 score: 0.7274131344885875
# Average MSE score: 0.28430906
# fold 0
# all param: 2048 32 258 0.001 10000
# Early stopping after 1184 epochs
# fold 1
# all param: 2048 32 258 0.001 10000
# Early stopping after 1505 epochs
# fold 2
# all param: 2048 32 258 0.001 10000
# Early stopping after 1329 epochs
# fold 3
# all param: 2048 32 258 0.001 10000
# Early stopping after 1183 epochs
# fold 4
# all param: 2048 32 258 0.001 10000
# Early stopping after 812 epochs
# fold 5
# all param: 2048 32 258 0.001 10000
# Early stopping after 1073 epochs
# fold 6
# all param: 2048 32 258 0.001 10000
# Early stopping after 893 epochs
# fold 7
# all param: 2048 32 258 0.001 10000
# Early stopping after 978 epochs
# fold 8
# all param: 2048 32 258 0.001 10000
# Early stopping after 1063 epochs
# fold 9
# all param: 2048 32 258 0.001 10000
# Early stopping after 1253 epochs
# Average R^2 score: 0.7145825089166393
# Average MSE score: 0.2975333
# fold 0
# all param: 2048 64 128 0.001 10000
# Early stopping after 1152 epochs
# fold 1
# all param: 2048 64 128 0.001 10000
# Early stopping after 1279 epochs
# fold 2
# all param: 2048 64 128 0.001 10000
# Early stopping after 1202 epochs
# fold 3
# all param: 2048 64 128 0.001 10000
# Early stopping after 1295 epochs
# fold 4
# all param: 2048 64 128 0.001 10000
# Early stopping after 1535 epochs
# fold 5
# all param: 2048 64 128 0.001 10000
# Early stopping after 1043 epochs
# fold 6
# all param: 2048 64 128 0.001 10000
# Early stopping after 1114 epochs
# fold 7
# all param: 2048 64 128 0.001 10000
# Early stopping after 1656 epochs
# fold 8
# all param: 2048 64 128 0.001 10000
# Early stopping after 1296 epochs
# fold 9
# all param: 2048 64 128 0.001 10000
# Early stopping after 1215 epochs
# Average R^2 score: 0.7143311154049256
# Average MSE score: 0.29771924
# fold 0
# all param: 2048 64 258 0.001 10000
# Early stopping after 943 epochs
# fold 1
# all param: 2048 64 258 0.001 10000
# Early stopping after 1042 epochs
# fold 2
# all param: 2048 64 258 0.001 10000
# Early stopping after 1018 epochs
# fold 3
# all param: 2048 64 258 0.001 10000
# Early stopping after 1229 epochs
# fold 4
# all param: 2048 64 258 0.001 10000
# Early stopping after 944 epochs
# fold 5
# all param: 2048 64 258 0.001 10000
# Early stopping after 1007 epochs
# fold 6
# all param: 2048 64 258 0.001 10000
# Early stopping after 1204 epochs
# fold 7
# all param: 2048 64 258 0.001 10000
# Early stopping after 1555 epochs
# fold 8
# all param: 2048 64 258 0.001 10000
# Early stopping after 983 epochs
# fold 9
# all param: 2048 64 258 0.001 10000
# Early stopping after 1618 epochs
# Average R^2 score: 0.718189181861728
# Average MSE score: 0.29364532
# fold 0
# all param: 4096 32 128 0.001 10000
# Early stopping after 2618 epochs
# fold 1
# all param: 4096 32 128 0.001 10000
# Early stopping after 1582 epochs
# fold 2
# all param: 4096 32 128 0.001 10000
# Early stopping after 1630 epochs
# fold 3
# all param: 4096 32 128 0.001 10000
# Early stopping after 929 epochs
# fold 4
# all param: 4096 32 128 0.001 10000
# Early stopping after 2318 epochs
# fold 5
# all param: 4096 32 128 0.001 10000
# Early stopping after 1947 epochs
# fold 6
# all param: 4096 32 128 0.001 10000
# Early stopping after 1788 epochs
# fold 7
# all param: 4096 32 128 0.001 10000
# Early stopping after 2243 epochs
# fold 8
# all param: 4096 32 128 0.001 10000
# Early stopping after 1632 epochs
# fold 9
# all param: 4096 32 128 0.001 10000
# Early stopping after 2078 epochs
# Average R^2 score: 0.7327812043233455
# Average MSE score: 0.27868992
# fold 0
# all param: 4096 32 258 0.001 10000
# Early stopping after 1491 epochs
# fold 1
# all param: 4096 32 258 0.001 10000
# Early stopping after 2430 epochs
# fold 2
# all param: 4096 32 258 0.001 10000
# Early stopping after 1207 epochs
# fold 3
# all param: 4096 32 258 0.001 10000
# Early stopping after 1602 epochs
# fold 4
# all param: 4096 32 258 0.001 10000
# Early stopping after 1571 epochs
# fold 5
# all param: 4096 32 258 0.001 10000
# Early stopping after 2345 epochs
# fold 6
# all param: 4096 32 258 0.001 10000
# Early stopping after 1860 epochs
# fold 7
# all param: 4096 32 258 0.001 10000
# Early stopping after 1883 epochs
# fold 8
# all param: 4096 32 258 0.001 10000
# Early stopping after 1213 epochs
# fold 9
# all param: 4096 32 258 0.001 10000
# Early stopping after 1369 epochs
# Average R^2 score: 0.727463047847493
# Average MSE score: 0.28409752
# fold 0
# all param: 4096 64 128 0.001 10000
# Early stopping after 1645 epochs
# fold 1
# all param: 4096 64 128 0.001 10000
# Early stopping after 2007 epochs
# fold 2
# all param: 4096 64 128 0.001 10000
# Early stopping after 1655 epochs
# fold 3
# all param: 4096 64 128 0.001 10000
# Early stopping after 1238 epochs
# fold 4
# all param: 4096 64 128 0.001 10000
# Early stopping after 1308 epochs
# fold 5
# all param: 4096 64 128 0.001 10000
# Early stopping after 1583 epochs
# fold 6
# all param: 4096 64 128 0.001 10000
# Early stopping after 1855 epochs
# fold 7
# all param: 4096 64 128 0.001 10000
# Early stopping after 1061 epochs
# fold 8
# all param: 4096 64 128 0.001 10000
# Early stopping after 853 epochs
# fold 9
# all param: 4096 64 128 0.001 10000
# Early stopping after 1864 epochs
# Average R^2 score: 0.7329718019935436
# Average MSE score: 0.27837884
# fold 0
# all param: 4096 64 258 0.001 10000
# Early stopping after 1795 epochs
# fold 1
# all param: 4096 64 258 0.001 10000
# Early stopping after 1365 epochs
# fold 2
# all param: 4096 64 258 0.001 10000
# Early stopping after 1466 epochs
# fold 3
# all param: 4096 64 258 0.001 10000
# Early stopping after 2135 epochs
# fold 4
# all param: 4096 64 258 0.001 10000
# Early stopping after 1350 epochs
# fold 5
# all param: 4096 64 258 0.001 10000
# Early stopping after 1608 epochs
# fold 6
# all param: 4096 64 258 0.001 10000
# Early stopping after 1275 epochs
# fold 7
# all param: 4096 64 258 0.001 10000
# Early stopping after 1655 epochs
# fold 8
# all param: 4096 64 258 0.001 10000
# Early stopping after 1126 epochs
# fold 9
# all param: 4096 64 258 0.001 10000
# Early stopping after 1267 epochs
# Average R^2 score: 0.7320265012233976
# Average MSE score: 0.2794082
# ------------------MLP END-----------------
